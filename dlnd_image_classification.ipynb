# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    result = np.zeros((len(x),10))
    for i in range(len(x)):
        result[i,x[i]] = 1
    
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    image_input = tf.placeholder(tf.float32, shape=(None,image_shape[0],image_shape[1],image_shape[2]),name='x')
    return image_input


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    label_input = tf.placeholder(tf.float32, shape=(None,n_classes),name='y')
    return label_input


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    prob_input = tf.placeholder(tf.float32,name='keep_prob')
    return prob_input


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    conv_num_inputs = x_tensor.get_shape().as_list()[3]
    padding = 'SAME'
    conv_stride = [1,conv_strides[0],conv_strides[1],1]
    pool_shape =[1,pool_ksize[0],pool_ksize[1],1]
    pool_stride = [1,pool_strides[0],pool_strides[1],1]
    F_W = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],conv_num_inputs,conv_num_outputs],mean = .0, stddev= .01)) 
    F_b = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_layer = tf.nn.conv2d(x_tensor,F_W, conv_stride,padding, use_cudnn_on_gpu=True) + F_b
    nonlinear_layer = tf.nn.relu(conv_layer)
    pool_layer = tf.nn.max_pool(nonlinear_layer,pool_shape,pool_stride,padding)
    
    return pool_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    flattened_size = shape[1]*shape[2]*shape[3]
    flat_tensor = tf.reshape(x_tensor,(-1,flattened_size))
    return flat_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_inputs = x_tensor.get_shape().as_list()[1]
    F_W = tf.Variable(tf.truncated_normal([num_inputs,num_outputs], mean = .0, stddev = .01)) 
    F_b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.nn.relu(tf.add(tf.matmul(x_tensor,F_W),F_b))
    
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_inputs = x_tensor.get_shape().as_list()[1]
    F_W = tf.Variable(tf.truncated_normal([num_inputs,num_outputs], mean = .0, stddev = .01)) 
    F_b = tf.Variable(tf.zeros(num_outputs))
    out = tf.add(tf.matmul(x_tensor,F_W),F_b)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)trides=(1,1))
    model = conv2d_maxpool(x, conv_num_outputs= 16, conv_ksize=(3,3), conv_strides=(1,1) , pool_ksize=(2,2), pool_strides=(1,1))
    model = conv2d_maxpool(model, conv_num_outputs= 16,  conv_ksize=(3,3), conv_strides=(1,1) , pool_ksize=(2,2), pool_strides=(1,1))
    model = conv2d_maxpool(model, conv_num_outputs= 16, conv_ksize=(3,3), conv_strides=(1,1) , pool_ksize=(2,2), pool_strides=(1,1))
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model = flatten(model) 
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
   # model = fully_conn(model,512)
  #  model = fully_conn(model,512)
    model = fully_conn(model,128)
    model = tf.nn.dropout(model,keep_prob)
    model = fully_conn(model,64)
    #model = fully_conn(model,512)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    model = output(model,10)
    
    # TODO: return output
    return model


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# AccuracyTests Passed
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x : feature_batch,
        y : label_batch,
        keep_prob: 1.0
    })
    valid_accuracy = session.run(accuracy, feed_dict={
        x : valid_features, 
        y : valid_labels,
        keep_prob: 1.0
    })
    print('| Loss: {:>10.4f} | Validation Accuracy: {:.6f}'.format(loss, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  | Loss:     2.3028 | Validation Accuracy: 0.099800
# Epoch  2, CIFAR-10 Batch 1:  | Loss:     2.2836 | Validation Accuracy: 0.149400
# Epoch  3, CIFAR-10 Batch 1:  | Loss:     2.1717 | Validation Accuracy: 0.210200
# Epoch  4, CIFAR-10 Batch 1:  | Loss:     2.1206 | Validation Accuracy: 0.193200
# Epoch  5, CIFAR-10 Batch 1:  | Loss:     2.0963 | Validation Accuracy: 0.197400
# Epoch  6, CIFAR-10 Batch 1:  | Loss:     2.0935 | Validation Accuracy: 0.196600
# Epoch  7, CIFAR-10 Batch 1:  | Loss:     2.0527 | Validation Accuracy: 0.217800
# Epoch  8, CIFAR-10 Batch 1:  | Loss:     2.0397 | Validation Accuracy: 0.222400
# Epoch  9, CIFAR-10 Batch 1:  | Loss:     2.0176 | Validation Accuracy: 0.241600
# Epoch 10, CIFAR-10 Batch 1:  | Loss:     2.0006 | Validation Accuracy: 0.247800
# Epoch 11, CIFAR-10 Batch 1:  | Loss:     1.9892 | Validation Accuracy: 0.250000
# Epoch 12, CIFAR-10 Batch 1:  | Loss:     1.9744 | Validation Accuracy: 0.265200
# Epoch 13, CIFAR-10 Batch 1:  | Loss:     1.9687 | Validation Accuracy: 0.293200
# Epoch 14, CIFAR-10 Batch 1:  | Loss:     1.9379 | Validation Accuracy: 0.300800
# Epoch 15, CIFAR-10 Batch 1:  | Loss:     1.9183 | Validation Accuracy: 0.303400
# Epoch 16, CIFAR-10 Batch 1:  | Loss:     1.9073 | Validation Accuracy: 0.302400
# Epoch 17, CIFAR-10 Batch 1:  | Loss:     1.8712 | Validation Accuracy: 0.334200
# Epoch 18, CIFAR-10 Batch 1:  | Loss:     1.8328 | Validation Accuracy: 0.346000
# Epoch 19, CIFAR-10 Batch 1:  | Loss:     1.8150 | Validation Accuracy: 0.353000
# Epoch 20, CIFAR-10 Batch 1:  | Loss:     1.7750 | Validation Accuracy: 0.343800
# Epoch 21, CIFAR-10 Batch 1:  | Loss:     1.7403 | Validation Accuracy: 0.367000
# Epoch 22, CIFAR-10 Batch 1:  | Loss:     1.6985 | Validation Accuracy: 0.373000
# Epoch 23, CIFAR-10 Batch 1:  | Loss:     1.6703 | Validation Accuracy: 0.373600
# Epoch 24, CIFAR-10 Batch 1:  | Loss:     1.6346 | Validation Accuracy: 0.387400
# Epoch 25, CIFAR-10 Batch 1:  | Loss:     1.6203 | Validation Accuracy: 0.390200
# Epoch 26, CIFAR-10 Batch 1:  | Loss:     1.5944 | Validation Accuracy: 0.398200
# Epoch 27, CIFAR-10 Batch 1:  | Loss:     1.5734 | Validation Accuracy: 0.405600
# Epoch 28, CIFAR-10 Batch 1:  | Loss:     1.5438 | Validation Accuracy: 0.413000
# Epoch 29, CIFAR-10 Batch 1:  | Loss:     1.5300 | Validation Accuracy: 0.420400
# Epoch 30, CIFAR-10 Batch 1:  | Loss:     1.5209 | Validation Accuracy: 0.425400
# Epoch 31, CIFAR-10 Batch 1:  | Loss:     1.4999 | Validation Accuracy: 0.430800
# Epoch 32, CIFAR-10 Batch 1:  | Loss:     1.4810 | Validation Accuracy: 0.430400
# Epoch 33, CIFAR-10 Batch 1:  | Loss:     1.4665 | Validation Accuracy: 0.446000
# Epoch 34, CIFAR-10 Batch 1:  | Loss:     1.4429 | Validation Accuracy: 0.440000
# Epoch 35, CIFAR-10 Batch 1:  | Loss:     1.4229 | Validation Accuracy: 0.444600
# Epoch 36, CIFAR-10 Batch 1:  | Loss:     1.4088 | Validation Accuracy: 0.454000
# Epoch 37, CIFAR-10 Batch 1:  | Loss:     1.3827 | Validation Accuracy: 0.464800
# Epoch 38, CIFAR-10 Batch 1:  | Loss:     1.3713 | Validation Accuracy: 0.459400
# Epoch 39, CIFAR-10 Batch 1:  | Loss:     1.3697 | Validation Accuracy: 0.446400
# Epoch 40, CIFAR-10 Batch 1:  | Loss:     1.3308 | Validation Accuracy: 0.467800
# Epoch 41, CIFAR-10 Batch 1:  | Loss:     1.3282 | Validation Accuracy: 0.472800
# Epoch 42, CIFAR-10 Batch 1:  | Loss:     1.3231 | Validation Accuracy: 0.474200
# Epoch 43, CIFAR-10 Batch 1:  | Loss:     1.3104 | Validation Accuracy: 0.474600
# Epoch 44, CIFAR-10 Batch 1:  | Loss:     1.3006 | Validation Accuracy: 0.481000
# Epoch 45, CIFAR-10 Batch 1:  | Loss:     1.2483 | Validation Accuracy: 0.479000
# Epoch 46, CIFAR-10 Batch 1:  | Loss:     1.2373 | Validation Accuracy: 0.485800
# Epoch 47, CIFAR-10 Batch 1:  | Loss:     1.2527 | Validation Accuracy: 0.483800
# Epoch 48, CIFAR-10 Batch 1:  | Loss:     1.2207 | Validation Accuracy: 0.484400
# Epoch 49, CIFAR-10 Batch 1:  | Loss:     1.2113 | Validation Accuracy: 0.489000
# Epoch 50, CIFAR-10 Batch 1:  | Loss:     1.1837 | Validation Accuracy: 0.487800
# Epoch 51, CIFAR-10 Batch 1:  | Loss:     1.1743 | Validation Accuracy: 0.495000
# Epoch 52, CIFAR-10 Batch 1:  | Loss:     1.1633 | Validation Accuracy: 0.492400
# Epoch 53, CIFAR-10 Batch 1:  | Loss:     1.1696 | Validation Accuracy: 0.494800
# Epoch 54, CIFAR-10 Batch 1:  | Loss:     1.1368 | Validation Accuracy: 0.498800
# Epoch 55, CIFAR-10 Batch 1:  | Loss:     1.1130 | Validation Accuracy: 0.499400
# Epoch 56, CIFAR-10 Batch 1:  | Loss:     1.0969 | Validation Accuracy: 0.509000
# Epoch 57, CIFAR-10 Batch 1:  | Loss:     1.0936 | Validation Accuracy: 0.509000
# Epoch 58, CIFAR-10 Batch 1:  | Loss:     1.0869 | Validation Accuracy: 0.494000
# Epoch 59, CIFAR-10 Batch 1:  | Loss:     1.0493 | Validation Accuracy: 0.502200
# Epoch 60, CIFAR-10 Batch 1:  | Loss:     1.0476 | Validation Accuracy: 0.510600
# Epoch 61, CIFAR-10 Batch 1:  | Loss:     1.0188 | Validation Accuracy: 0.512200
# Epoch 62, CIFAR-10 Batch 1:  | Loss:     0.9985 | Validation Accuracy: 0.510800
# Epoch 63, CIFAR-10 Batch 1:  | Loss:     1.0058 | Validation Accuracy: 0.508800
# Epoch 64, CIFAR-10 Batch 1:  | Loss:     1.0048 | Validation Accuracy: 0.504800
# Epoch 65, CIFAR-10 Batch 1:  | Loss:     1.0111 | Validation Accuracy: 0.501000
# Epoch 66, CIFAR-10 Batch 1:  | Loss:     0.9721 | Validation Accuracy: 0.507000
# Epoch 67, CIFAR-10 Batch 1:  | Loss:     0.9830 | Validation Accuracy: 0.499800
# Epoch 68, CIFAR-10 Batch 1:  | Loss:     0.9683 | Validation Accuracy: 0.503000
# Epoch 69, CIFAR-10 Batch 1:  | Loss:     0.9882 | Validation Accuracy: 0.489000
# Epoch 70, CIFAR-10 Batch 1:  | Loss:     1.0227 | Validation Accuracy: 0.478800
# Epoch 71, CIFAR-10 Batch 1:  | Loss:     0.9664 | Validation Accuracy: 0.500600
# Epoch 72, CIFAR-10 Batch 1:  | Loss:     0.9836 | Validation Accuracy: 0.489000
# Epoch 73, CIFAR-10 Batch 1:  | Loss:     1.0504 | Validation Accuracy: 0.478600
# Epoch 74, CIFAR-10 Batch 1:  | Loss:     0.8899 | Validation Accuracy: 0.520400
# Epoch 75, CIFAR-10 Batch 1:  | Loss:     0.8823 | Validation Accuracy: 0.504200
# Epoch 76, CIFAR-10 Batch 1:  | Loss:     0.8646 | Validation Accuracy: 0.505200
# Epoch 77, CIFAR-10 Batch 1:  | Loss:     0.8615 | Validation Accuracy: 0.499400
# Epoch 78, CIFAR-10 Batch 1:  | Loss:     0.8750 | Validation Accuracy: 0.498800
# Epoch 79, CIFAR-10 Batch 1:  | Loss:     0.8579 | Validation Accuracy: 0.500600
# Epoch 80, CIFAR-10 Batch 1:  | Loss:     0.8275 | Validation Accuracy: 0.509800
# Epoch 81, CIFAR-10 Batch 1:  | Loss:     0.8340 | Validation Accuracy: 0.510800
# Epoch 82, CIFAR-10 Batch 1:  | Loss:     0.8118 | Validation Accuracy: 0.511600
# Epoch 83, CIFAR-10 Batch 1:  | Loss:     0.8070 | Validation Accuracy: 0.510000
# Epoch 84, CIFAR-10 Batch 1:  | Loss:     0.7715 | Validation Accuracy: 0.512800
# Epoch 85, CIFAR-10 Batch 1:  | Loss:     0.7756 | Validation Accuracy: 0.510800
# Epoch 86, CIFAR-10 Batch 1:  | Loss:     0.7448 | Validation Accuracy: 0.515000
# Epoch 87, CIFAR-10 Batch 1:  | Loss:     0.7339 | Validation Accuracy: 0.523800
# Epoch 88, CIFAR-10 Batch 1:  | Loss:     0.7335 | Validation Accuracy: 0.524000
# Epoch 89, CIFAR-10 Batch 1:  | Loss:     0.7198 | Validation Accuracy: 0.520200
# Epoch 90, CIFAR-10 Batch 1:  | Loss:     0.7066 | Validation Accuracy: 0.511000
# Epoch 91, CIFAR-10 Batch 1:  | Loss:     0.6869 | Validation Accuracy: 0.519600
# Epoch 92, CIFAR-10 Batch 1:  | Loss:     0.6767 | Validation Accuracy: 0.518200
# Epoch 93, CIFAR-10 Batch 1:  | Loss:     0.6872 | Validation Accuracy: 0.512000
# Epoch 94, CIFAR-10 Batch 1:  | Loss:     0.6784 | Validation Accuracy: 0.515800
# Epoch 95, CIFAR-10 Batch 1:  | Loss:     0.6746 | Validation Accuracy: 0.516800
# Epoch 96, CIFAR-10 Batch 1:  | Loss:     0.6474 | Validation Accuracy: 0.521000
# Epoch 97, CIFAR-10 Batch 1:  | Loss:     0.6602 | Validation Accuracy: 0.511600
# Epoch 98, CIFAR-10 Batch 1:  | Loss:     0.6664 | Validation Accuracy: 0.514200
# Epoch 99, CIFAR-10 Batch 1:  | Loss:     0.6254 | Validation Accuracy: 0.511200
# Epoch 100, CIFAR-10 Batch 1:  | Loss:     0.6468 | Validation Accuracy: 0.511200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  | Loss:     2.3027 | Validation Accuracy: 0.099800
# Epoch  1, CIFAR-10 Batch 2:  | Loss:     2.2981 | Validation Accuracy: 0.116600
# Epoch  1, CIFAR-10 Batch 3:  | Loss:     2.2316 | Validation Accuracy: 0.171400
# Epoch  1, CIFAR-10 Batch 4:  | Loss:     2.1159 | Validation Accuracy: 0.173200
# Epoch  1, CIFAR-10 Batch 5:  | Loss:     2.0347 | Validation Accuracy: 0.239200
# Epoch  2, CIFAR-10 Batch 1:  | Loss:     2.0596 | Validation Accuracy: 0.233600
# Epoch  2, CIFAR-10 Batch 2:  | Loss:     1.9516 | Validation Accuracy: 0.279200
# Epoch  2, CIFAR-10 Batch 3:  | Loss:     1.9112 | Validation Accuracy: 0.282800
# Epoch  2, CIFAR-10 Batch 4:  | Loss:     1.8661 | Validation Accuracy: 0.297400
# Epoch  2, CIFAR-10 Batch 5:  | Loss:     1.9093 | Validation Accuracy: 0.298800
# Epoch  3, CIFAR-10 Batch 1:  | Loss:     1.9888 | Validation Accuracy: 0.298600
# Epoch  3, CIFAR-10 Batch 2:  | Loss:     1.8629 | Validation Accuracy: 0.307800
# Epoch  3, CIFAR-10 Batch 3:  | Loss:     1.8257 | Validation Accuracy: 0.307400
# Epoch  3, CIFAR-10 Batch 4:  | Loss:     1.7549 | Validation Accuracy: 0.321400
# Epoch  3, CIFAR-10 Batch 5:  | Loss:     1.8456 | Validation Accuracy: 0.322800
# Epoch  4, CIFAR-10 Batch 1:  | Loss:     1.9082 | Validation Accuracy: 0.334000
# Epoch  4, CIFAR-10 Batch 2:  | Loss:     1.7510 | Validation Accuracy: 0.339600
# Epoch  4, CIFAR-10 Batch 3:  | Loss:     1.6905 | Validation Accuracy: 0.341800
# Epoch  4, CIFAR-10 Batch 4:  | Loss:     1.6543 | Validation Accuracy: 0.342600
# Epoch  4, CIFAR-10 Batch 5:  | Loss:     1.7738 | Validation Accuracy: 0.357400
# Epoch  5, CIFAR-10 Batch 1:  | Loss:     1.8434 | Validation Accuracy: 0.348200
# Epoch  5, CIFAR-10 Batch 2:  | Loss:     1.7058 | Validation Accuracy: 0.368800
# Epoch  5, CIFAR-10 Batch 3:  | Loss:     1.6425 | Validation Accuracy: 0.356800
# Epoch  5, CIFAR-10 Batch 4:  | Loss:     1.5981 | Validation Accuracy: 0.367200
# Epoch  5, CIFAR-10 Batch 5:  | Loss:     1.7226 | Validation Accuracy: 0.371400
# Epoch  6, CIFAR-10 Batch 1:  | Loss:     1.8136 | Validation Accuracy: 0.358400
# Epoch  6, CIFAR-10 Batch 2:  | Loss:     1.6582 | Validation Accuracy: 0.365400
# Epoch  6, CIFAR-10 Batch 3:  | Loss:     1.5788 | Validation Accuracy: 0.374000
# Epoch  6, CIFAR-10 Batch 4:  | Loss:     1.5513 | Validation Accuracy: 0.377800
# Epoch  6, CIFAR-10 Batch 5:  | Loss:     1.6817 | Validation Accuracy: 0.380200
# Epoch  7, CIFAR-10 Batch 1:  | Loss:     1.7738 | Validation Accuracy: 0.376200
# Epoch  7, CIFAR-10 Batch 2:  | Loss:     1.6437 | Validation Accuracy: 0.371400
# Epoch  7, CIFAR-10 Batch 3:  | Loss:     1.5484 | Validation Accuracy: 0.387000
# Epoch  7, CIFAR-10 Batch 4:  | Loss:     1.5057 | Validation Accuracy: 0.399800
# Epoch  7, CIFAR-10 Batch 5:  | Loss:     1.6429 | Validation Accuracy: 0.398800
# Epoch  8, CIFAR-10 Batch 1:  | Loss:     1.7217 | Validation Accuracy: 0.395600
# Epoch  8, CIFAR-10 Batch 2:  | Loss:     1.5465 | Validation Accuracy: 0.401200
# Epoch  8, CIFAR-10 Batch 3:  | Loss:     1.4837 | Validation Accuracy: 0.407400
# Epoch  8, CIFAR-10 Batch 4:  | Loss:     1.4632 | Validation Accuracy: 0.416200
# Epoch  8, CIFAR-10 Batch 5:  | Loss:     1.5973 | Validation Accuracy: 0.416200
# Epoch  9, CIFAR-10 Batch 1:  | Loss:     1.6647 | Validation Accuracy: 0.413200
# Epoch  9, CIFAR-10 Batch 2:  | Loss:     1.4936 | Validation Accuracy: 0.429600
# Epoch  9, CIFAR-10 Batch 3:  | Loss:     1.4107 | Validation Accuracy: 0.429000
# Epoch  9, CIFAR-10 Batch 4:  | Loss:     1.3970 | Validation Accuracy: 0.436600
# Epoch  9, CIFAR-10 Batch 5:  | Loss:     1.5215 | Validation Accuracy: 0.441800
# Epoch 10, CIFAR-10 Batch 1:  | Loss:     1.5868 | Validation Accuracy: 0.436800
# Epoch 10, CIFAR-10 Batch 2:  | Loss:     1.4027 | Validation Accuracy: 0.453800
# Epoch 10, CIFAR-10 Batch 3:  | Loss:     1.3352 | Validation Accuracy: 0.455200
# Epoch 10, CIFAR-10 Batch 4:  | Loss:     1.3508 | Validation Accuracy: 0.449400
# Epoch 10, CIFAR-10 Batch 5:  | Loss:     1.4490 | Validation Accuracy: 0.460400
# Epoch 11, CIFAR-10 Batch 1:  | Loss:     1.5364 | Validation Accuracy: 0.463800
# Epoch 11, CIFAR-10 Batch 2:  | Loss:     1.3718 | Validation Accuracy: 0.475800
# Epoch 11, CIFAR-10 Batch 3:  | Loss:     1.2896 | Validation Accuracy: 0.472800
# Epoch 11, CIFAR-10 Batch 4:  | Loss:     1.2719 | Validation Accuracy: 0.484600
# Epoch 11, CIFAR-10 Batch 5:  | Loss:     1.4018 | Validation Accuracy: 0.476800
# Epoch 12, CIFAR-10 Batch 1:  | Loss:     1.4757 | Validation Accuracy: 0.472600
# Epoch 12, CIFAR-10 Batch 2:  | Loss:     1.3339 | Validation Accuracy: 0.487000
# Epoch 12, CIFAR-10 Batch 3:  | Loss:     1.2347 | Validation Accuracy: 0.487200
# Epoch 12, CIFAR-10 Batch 4:  | Loss:     1.2323 | Validation Accuracy: 0.489000
# Epoch 12, CIFAR-10 Batch 5:  | Loss:     1.3774 | Validation Accuracy: 0.481600
# Epoch 13, CIFAR-10 Batch 1:  | Loss:     1.4524 | Validation Accuracy: 0.484000
# Epoch 13, CIFAR-10 Batch 2:  | Loss:     1.2895 | Validation Accuracy: 0.508400
# Epoch 13, CIFAR-10 Batch 3:  | Loss:     1.2203 | Validation Accuracy: 0.500800
# Epoch 13, CIFAR-10 Batch 4:  | Loss:     1.2058 | Validation Accuracy: 0.505400
# Epoch 13, CIFAR-10 Batch 5:  | Loss:     1.3562 | Validation Accuracy: 0.493200
# Epoch 14, CIFAR-10 Batch 1:  | Loss:     1.3753 | Validation Accuracy: 0.507200
# Epoch 14, CIFAR-10 Batch 2:  | Loss:     1.2510 | Validation Accuracy: 0.505400
# Epoch 14, CIFAR-10 Batch 3:  | Loss:     1.1791 | Validation Accuracy: 0.509400
# Epoch 14, CIFAR-10 Batch 4:  | Loss:     1.1978 | Validation Accuracy: 0.499800
# Epoch 14, CIFAR-10 Batch 5:  | Loss:     1.3050 | Validation Accuracy: 0.510200
# Epoch 15, CIFAR-10 Batch 1:  | Loss:     1.3377 | Validation Accuracy: 0.516600
# Epoch 15, CIFAR-10 Batch 2:  | Loss:     1.2317 | Validation Accuracy: 0.509400
# Epoch 15, CIFAR-10 Batch 3:  | Loss:     1.1344 | Validation Accuracy: 0.520600
# Epoch 15, CIFAR-10 Batch 4:  | Loss:     1.1789 | Validation Accuracy: 0.502600
# Epoch 15, CIFAR-10 Batch 5:  | Loss:     1.2911 | Validation Accuracy: 0.516000
# Epoch 16, CIFAR-10 Batch 1:  | Loss:     1.3099 | Validation Accuracy: 0.518000
# Epoch 16, CIFAR-10 Batch 2:  | Loss:     1.2025 | Validation Accuracy: 0.509600
# Epoch 16, CIFAR-10 Batch 3:  | Loss:     1.1226 | Validation Accuracy: 0.529200
# Epoch 16, CIFAR-10 Batch 4:  | Loss:     1.1286 | Validation Accuracy: 0.522400
# Epoch 16, CIFAR-10 Batch 5:  | Loss:     1.2766 | Validation Accuracy: 0.517800
# Epoch 17, CIFAR-10 Batch 1:  | Loss:     1.2926 | Validation Accuracy: 0.524800
# Epoch 17, CIFAR-10 Batch 2:  | Loss:     1.1788 | Validation Accuracy: 0.523200
# Epoch 17, CIFAR-10 Batch 3:  | Loss:     1.1103 | Validation Accuracy: 0.529000
# Epoch 17, CIFAR-10 Batch 4:  | Loss:     1.1192 | Validation Accuracy: 0.527800
# Epoch 17, CIFAR-10 Batch 5:  | Loss:     1.2198 | Validation Accuracy: 0.533600
# Epoch 18, CIFAR-10 Batch 1:  | Loss:     1.2288 | Validation Accuracy: 0.537400
# Epoch 18, CIFAR-10 Batch 2:  | Loss:     1.1437 | Validation Accuracy: 0.543000
# Epoch 18, CIFAR-10 Batch 3:  | Loss:     1.0630 | Validation Accuracy: 0.541000
# Epoch 18, CIFAR-10 Batch 4:  | Loss:     1.0495 | Validation Accuracy: 0.545400
# Epoch 18, CIFAR-10 Batch 5:  | Loss:     1.1973 | Validation Accuracy: 0.541400
# Epoch 19, CIFAR-10 Batch 1:  | Loss:     1.2480 | Validation Accuracy: 0.524600
# Epoch 19, CIFAR-10 Batch 2:  | Loss:     1.1080 | Validation Accuracy: 0.546400
# Epoch 19, CIFAR-10 Batch 3:  | Loss:     1.0530 | Validation Accuracy: 0.543600
# Epoch 19, CIFAR-10 Batch 4:  | Loss:     1.0944 | Validation Accuracy: 0.526800
# Epoch 19, CIFAR-10 Batch 5:  | Loss:     1.1939 | Validation Accuracy: 0.539400
# Epoch 20, CIFAR-10 Batch 1:  | Loss:     1.1868 | Validation Accuracy: 0.547400
# Epoch 20, CIFAR-10 Batch 2:  | Loss:     1.0761 | Validation Accuracy: 0.556000
# Epoch 20, CIFAR-10 Batch 3:  | Loss:     1.0207 | Validation Accuracy: 0.548600
# Epoch 20, CIFAR-10 Batch 4:  | Loss:     1.0424 | Validation Accuracy: 0.540200
# Epoch 20, CIFAR-10 Batch 5:  | Loss:     1.1121 | Validation Accuracy: 0.554800
# Epoch 21, CIFAR-10 Batch 1:  | Loss:     1.1564 | Validation Accuracy: 0.556200
# Epoch 21, CIFAR-10 Batch 2:  | Loss:     1.0728 | Validation Accuracy: 0.551200
# Epoch 21, CIFAR-10 Batch 3:  | Loss:     0.9961 | Validation Accuracy: 0.556800
# Epoch 21, CIFAR-10 Batch 4:  | Loss:     0.9779 | Validation Accuracy: 0.558400
# Epoch 21, CIFAR-10 Batch 5:  | Loss:     1.0953 | Validation Accuracy: 0.566800
# Epoch 22, CIFAR-10 Batch 1:  | Loss:     1.1176 | Validation Accuracy: 0.560400
# Epoch 22, CIFAR-10 Batch 2:  | Loss:     1.0583 | Validation Accuracy: 0.556400
# Epoch 22, CIFAR-10 Batch 3:  | Loss:     0.9901 | Validation Accuracy: 0.556400
# Epoch 22, CIFAR-10 Batch 4:  | Loss:     1.0007 | Validation Accuracy: 0.551000
# Epoch 22, CIFAR-10 Batch 5:  | Loss:     1.0704 | Validation Accuracy: 0.566000
# Epoch 23, CIFAR-10 Batch 1:  | Loss:     1.1239 | Validation Accuracy: 0.564600
# Epoch 23, CIFAR-10 Batch 2:  | Loss:     1.0289 | Validation Accuracy: 0.553200
# Epoch 23, CIFAR-10 Batch 3:  | Loss:     0.9626 | Validation Accuracy: 0.563000
# Epoch 23, CIFAR-10 Batch 4:  | Loss:     0.9694 | Validation Accuracy: 0.559400
# Epoch 23, CIFAR-10 Batch 5:  | Loss:     1.0424 | Validation Accuracy: 0.575200
# Epoch 24, CIFAR-10 Batch 1:  | Loss:     1.1048 | Validation Accuracy: 0.560400
# Epoch 24, CIFAR-10 Batch 2:  | Loss:     1.0117 | Validation Accuracy: 0.560400
# Epoch 24, CIFAR-10 Batch 3:  | Loss:     0.9703 | Validation Accuracy: 0.561000
# Epoch 24, CIFAR-10 Batch 4:  | Loss:     0.9730 | Validation Accuracy: 0.557400
# Epoch 24, CIFAR-10 Batch 5:  | Loss:     1.0341 | Validation Accuracy: 0.567800
# Epoch 25, CIFAR-10 Batch 1:  | Loss:     1.0808 | Validation Accuracy: 0.574800
# Epoch 25, CIFAR-10 Batch 2:  | Loss:     1.0010 | Validation Accuracy: 0.568800
# Epoch 25, CIFAR-10 Batch 3:  | Loss:     0.9266 | Validation Accuracy: 0.575400
# Epoch 25, CIFAR-10 Batch 4:  | Loss:     0.9275 | Validation Accuracy: 0.564400
# Epoch 25, CIFAR-10 Batch 5:  | Loss:     0.9803 | Validation Accuracy: 0.578000
# Epoch 26, CIFAR-10 Batch 1:  | Loss:     1.0614 | Validation Accuracy: 0.578400
# Epoch 26, CIFAR-10 Batch 2:  | Loss:     0.9844 | Validation Accuracy: 0.565800
# Epoch 26, CIFAR-10 Batch 3:  | Loss:     0.9093 | Validation Accuracy: 0.569800
# Epoch 26, CIFAR-10 Batch 4:  | Loss:     0.9224 | Validation Accuracy: 0.572400
# Epoch 26, CIFAR-10 Batch 5:  | Loss:     1.0046 | Validation Accuracy: 0.575400
# Epoch 27, CIFAR-10 Batch 1:  | Loss:     1.0407 | Validation Accuracy: 0.581000
# Epoch 27, CIFAR-10 Batch 2:  | Loss:     0.9670 | Validation Accuracy: 0.569800
# Epoch 27, CIFAR-10 Batch 3:  | Loss:     0.8906 | Validation Accuracy: 0.588400
# Epoch 27, CIFAR-10 Batch 4:  | Loss:     0.9226 | Validation Accuracy: 0.574400
# Epoch 27, CIFAR-10 Batch 5:  | Loss:     0.9539 | Validation Accuracy: 0.588800
# Epoch 28, CIFAR-10 Batch 1:  | Loss:     1.0028 | Validation Accuracy: 0.582400
# Epoch 28, CIFAR-10 Batch 2:  | Loss:     0.9498 | Validation Accuracy: 0.584200
# Epoch 28, CIFAR-10 Batch 3:  | Loss:     0.8650 | Validation Accuracy: 0.587800
# Epoch 28, CIFAR-10 Batch 4:  | Loss:     0.8849 | Validation Accuracy: 0.582600
# Epoch 28, CIFAR-10 Batch 5:  | Loss:     0.9503 | Validation Accuracy: 0.584000
# Epoch 29, CIFAR-10 Batch 1:  | Loss:     1.0055 | Validation Accuracy: 0.582800
# Epoch 29, CIFAR-10 Batch 2:  | Loss:     0.9631 | Validation Accuracy: 0.566200
# Epoch 29, CIFAR-10 Batch 3:  | Loss:     0.8309 | Validation Accuracy: 0.590000
# Epoch 29, CIFAR-10 Batch 4:  | Loss:     0.8628 | Validation Accuracy: 0.594400
# Epoch 29, CIFAR-10 Batch 5:  | Loss:     0.9002 | Validation Accuracy: 0.598600
# Epoch 30, CIFAR-10 Batch 1:  | Loss:     0.9768 | Validation Accuracy: 0.597000
# Epoch 30, CIFAR-10 Batch 2:  | Loss:     0.9422 | Validation Accuracy: 0.568400
# Epoch 30, CIFAR-10 Batch 3:  | Loss:     0.8276 | Validation Accuracy: 0.589200
# Epoch 30, CIFAR-10 Batch 4:  | Loss:     0.8601 | Validation Accuracy: 0.584000
# Epoch 30, CIFAR-10 Batch 5:  | Loss:     0.8989 | Validation Accuracy: 0.600200
# Epoch 31, CIFAR-10 Batch 1:  | Loss:     0.9491 | Validation Accuracy: 0.596000
# Epoch 31, CIFAR-10 Batch 2:  | Loss:     0.9070 | Validation Accuracy: 0.583800
# Epoch 31, CIFAR-10 Batch 3:  | Loss:     0.8222 | Validation Accuracy: 0.587200
# Epoch 31, CIFAR-10 Batch 4:  | Loss:     0.8251 | Validation Accuracy: 0.597200
# Epoch 31, CIFAR-10 Batch 5:  | Loss:     0.8860 | Validation Accuracy: 0.600400
# Epoch 32, CIFAR-10 Batch 1:  | Loss:     0.9705 | Validation Accuracy: 0.586400
# Epoch 32, CIFAR-10 Batch 2:  | Loss:     0.9476 | Validation Accuracy: 0.558000
# Epoch 32, CIFAR-10 Batch 3:  | Loss:     0.8111 | Validation Accuracy: 0.595600
# Epoch 32, CIFAR-10 Batch 4:  | Loss:     0.8148 | Validation Accuracy: 0.599400
# Epoch 32, CIFAR-10 Batch 5:  | Loss:     0.8909 | Validation Accuracy: 0.595200
# Epoch 33, CIFAR-10 Batch 1:  | Loss:     0.9379 | Validation Accuracy: 0.603800
# Epoch 33, CIFAR-10 Batch 2:  | Loss:     0.8742 | Validation Accuracy: 0.592600
# Epoch 33, CIFAR-10 Batch 3:  | Loss:     0.7770 | Validation Accuracy: 0.592400
# Epoch 33, CIFAR-10 Batch 4:  | Loss:     0.7870 | Validation Accuracy: 0.602200
# Epoch 33, CIFAR-10 Batch 5:  | Loss:     0.8640 | Validation Accuracy: 0.595600
# Epoch 34, CIFAR-10 Batch 1:  | Loss:     0.9048 | Validation Accuracy: 0.605200
# Epoch 34, CIFAR-10 Batch 2:  | Loss:     0.8775 | Validation Accuracy: 0.599200
# Epoch 34, CIFAR-10 Batch 3:  | Loss:     0.7598 | Validation Accuracy: 0.609000
# Epoch 34, CIFAR-10 Batch 4:  | Loss:     0.7704 | Validation Accuracy: 0.607800
# Epoch 34, CIFAR-10 Batch 5:  | Loss:     0.8451 | Validation Accuracy: 0.601200
# Epoch 35, CIFAR-10 Batch 1:  | Loss:     0.8916 | Validation Accuracy: 0.608600
# Epoch 35, CIFAR-10 Batch 2:  | Loss:     0.8681 | Validation Accuracy: 0.599200
# Epoch 35, CIFAR-10 Batch 3:  | Loss:     0.7497 | Validation Accuracy: 0.606400
# Epoch 35, CIFAR-10 Batch 4:  | Loss:     0.7683 | Validation Accuracy: 0.606800
# Epoch 35, CIFAR-10 Batch 5:  | Loss:     0.8211 | Validation Accuracy: 0.599200
# Epoch 36, CIFAR-10 Batch 1:  | Loss:     0.8586 | Validation Accuracy: 0.610200
# Epoch 36, CIFAR-10 Batch 2:  | Loss:     0.8462 | Validation Accuracy: 0.601400
# Epoch 36, CIFAR-10 Batch 3:  | Loss:     0.7521 | Validation Accuracy: 0.609600
# Epoch 36, CIFAR-10 Batch 4:  | Loss:     0.7421 | Validation Accuracy: 0.615200
# Epoch 36, CIFAR-10 Batch 5:  | Loss:     0.8310 | Validation Accuracy: 0.598000
# Epoch 37, CIFAR-10 Batch 1:  | Loss:     0.8666 | Validation Accuracy: 0.612800
# Epoch 37, CIFAR-10 Batch 2:  | Loss:     0.8302 | Validation Accuracy: 0.601200
# Epoch 37, CIFAR-10 Batch 3:  | Loss:     0.7182 | Validation Accuracy: 0.610200
# Epoch 37, CIFAR-10 Batch 4:  | Loss:     0.7251 | Validation Accuracy: 0.612200
# Epoch 37, CIFAR-10 Batch 5:  | Loss:     0.7859 | Validation Accuracy: 0.606000
# Epoch 38, CIFAR-10 Batch 1:  | Loss:     0.8698 | Validation Accuracy: 0.611600
# Epoch 38, CIFAR-10 Batch 2:  | Loss:     0.8267 | Validation Accuracy: 0.614800
# Epoch 38, CIFAR-10 Batch 3:  | Loss:     0.7427 | Validation Accuracy: 0.603000
# Epoch 38, CIFAR-10 Batch 4:  | Loss:     0.7238 | Validation Accuracy: 0.605800
# Epoch 38, CIFAR-10 Batch 5:  | Loss:     0.7903 | Validation Accuracy: 0.603800
# Epoch 39, CIFAR-10 Batch 1:  | Loss:     0.8534 | Validation Accuracy: 0.609800
# Epoch 39, CIFAR-10 Batch 2:  | Loss:     0.8627 | Validation Accuracy: 0.611600
# Epoch 39, CIFAR-10 Batch 3:  | Loss:     0.7182 | Validation Accuracy: 0.606000
# Epoch 39, CIFAR-10 Batch 4:  | Loss:     0.7146 | Validation Accuracy: 0.609000
# Epoch 39, CIFAR-10 Batch 5:  | Loss:     0.7628 | Validation Accuracy: 0.607400
# Epoch 40, CIFAR-10 Batch 1:  | Loss:     0.8586 | Validation Accuracy: 0.598000
# Epoch 40, CIFAR-10 Batch 2:  | Loss:     0.8425 | Validation Accuracy: 0.607600
# Epoch 40, CIFAR-10 Batch 3:  | Loss:     0.7094 | Validation Accuracy: 0.605800
# Epoch 40, CIFAR-10 Batch 4:  | Loss:     0.6867 | Validation Accuracy: 0.614000
# Epoch 40, CIFAR-10 Batch 5:  | Loss:     0.7643 | Validation Accuracy: 0.606000
# Epoch 41, CIFAR-10 Batch 1:  | Loss:     0.7928 | Validation Accuracy: 0.608200
# Epoch 41, CIFAR-10 Batch 2:  | Loss:     0.8705 | Validation Accuracy: 0.606600
# Epoch 41, CIFAR-10 Batch 3:  | Loss:     0.6918 | Validation Accuracy: 0.613800
# Epoch 41, CIFAR-10 Batch 4:  | Loss:     0.6816 | Validation Accuracy: 0.620600
# Epoch 41, CIFAR-10 Batch 5:  | Loss:     0.7312 | Validation Accuracy: 0.609800
# Epoch 42, CIFAR-10 Batch 1:  | Loss:     0.7875 | Validation Accuracy: 0.609000
# Epoch 42, CIFAR-10 Batch 2:  | Loss:     0.8523 | Validation Accuracy: 0.602600
# Epoch 42, CIFAR-10 Batch 3:  | Loss:     0.6686 | Validation Accuracy: 0.618400
# Epoch 42, CIFAR-10 Batch 4:  | Loss:     0.6894 | Validation Accuracy: 0.617200
# Epoch 42, CIFAR-10 Batch 5:  | Loss:     0.7292 | Validation Accuracy: 0.611000
# Epoch 43, CIFAR-10 Batch 1:  | Loss:     0.7570 | Validation Accuracy: 0.608200
# Epoch 43, CIFAR-10 Batch 2:  | Loss:     0.8243 | Validation Accuracy: 0.614000
# Epoch 43, CIFAR-10 Batch 3:  | Loss:     0.6601 | Validation Accuracy: 0.615000
# Epoch 43, CIFAR-10 Batch 4:  | Loss:     0.6666 | Validation Accuracy: 0.618200
# Epoch 43, CIFAR-10 Batch 5:  | Loss:     0.6864 | Validation Accuracy: 0.619000
# Epoch 44, CIFAR-10 Batch 1:  | Loss:     0.7276 | Validation Accuracy: 0.618600
# Epoch 44, CIFAR-10 Batch 2:  | Loss:     0.7699 | Validation Accuracy: 0.613000
# Epoch 44, CIFAR-10 Batch 3:  | Loss:     0.6795 | Validation Accuracy: 0.613200
# Epoch 44, CIFAR-10 Batch 4:  | Loss:     0.6623 | Validation Accuracy: 0.619200
# Epoch 44, CIFAR-10 Batch 5:  | Loss:     0.6776 | Validation Accuracy: 0.618600
# Epoch 45, CIFAR-10 Batch 1:  | Loss:     0.7398 | Validation Accuracy: 0.612000
# Epoch 45, CIFAR-10 Batch 2:  | Loss:     0.7830 | Validation Accuracy: 0.612800
# Epoch 45, CIFAR-10 Batch 3:  | Loss:     0.6506 | Validation Accuracy: 0.616600
# Epoch 45, CIFAR-10 Batch 4:  | Loss:     0.6452 | Validation Accuracy: 0.626400
# Epoch 45, CIFAR-10 Batch 5:  | Loss:     0.6677 | Validation Accuracy: 0.620200
# Epoch 46, CIFAR-10 Batch 1:  | Loss:     0.6991 | Validation Accuracy: 0.613000
# Epoch 46, CIFAR-10 Batch 2:  | Loss:     0.7435 | Validation Accuracy: 0.611600
# Epoch 46, CIFAR-10 Batch 3:  | Loss:     0.6576 | Validation Accuracy: 0.616600
# Epoch 46, CIFAR-10 Batch 4:  | Loss:     0.6212 | Validation Accuracy: 0.621000
# Epoch 46, CIFAR-10 Batch 5:  | Loss:     0.6917 | Validation Accuracy: 0.617200
# Epoch 47, CIFAR-10 Batch 1:  | Loss:     0.6802 | Validation Accuracy: 0.615400
# Epoch 47, CIFAR-10 Batch 2:  | Loss:     0.7404 | Validation Accuracy: 0.614800
# Epoch 47, CIFAR-10 Batch 3:  | Loss:     0.6277 | Validation Accuracy: 0.628000
# Epoch 47, CIFAR-10 Batch 4:  | Loss:     0.6384 | Validation Accuracy: 0.616400
# Epoch 47, CIFAR-10 Batch 5:  | Loss:     0.6556 | Validation Accuracy: 0.615800
# Epoch 48, CIFAR-10 Batch 1:  | Loss:     0.7057 | Validation Accuracy: 0.610600
# Epoch 48, CIFAR-10 Batch 2:  | Loss:     0.7050 | Validation Accuracy: 0.622400
# Epoch 48, CIFAR-10 Batch 3:  | Loss:     0.6009 | Validation Accuracy: 0.623600
# Epoch 48, CIFAR-10 Batch 4:  | Loss:     0.6124 | Validation Accuracy: 0.618000
# Epoch 48, CIFAR-10 Batch 5:  | Loss:     0.6300 | Validation Accuracy: 0.622200
# Epoch 49, CIFAR-10 Batch 1:  | Loss:     0.6790 | Validation Accuracy: 0.616400
# Epoch 49, CIFAR-10 Batch 2:  | Loss:     0.7293 | Validation Accuracy: 0.620000
# Epoch 49, CIFAR-10 Batch 3:  | Loss:     0.5828 | Validation Accuracy: 0.625800
# Epoch 49, CIFAR-10 Batch 4:  | Loss:     0.6012 | Validation Accuracy: 0.627800
# Epoch 49, CIFAR-10 Batch 5:  | Loss:     0.6104 | Validation Accuracy: 0.629600
# Epoch 50, CIFAR-10 Batch 1:  | Loss:     0.6804 | Validation Accuracy: 0.613600
# Epoch 50, CIFAR-10 Batch 2:  | Loss:     0.7075 | Validation Accuracy: 0.619800
# Epoch 50, CIFAR-10 Batch 3:  | Loss:     0.5875 | Validation Accuracy: 0.620400
# Epoch 50, CIFAR-10 Batch 4:  | Loss:     0.5770 | Validation Accuracy: 0.618600
# Epoch 50, CIFAR-10 Batch 5:  | Loss:     0.5916 | Validation Accuracy: 0.626800
# Epoch 51, CIFAR-10 Batch 1:  | Loss:     0.6576 | Validation Accuracy: 0.620200
# Epoch 51, CIFAR-10 Batch 2:  | Loss:     0.6571 | Validation Accuracy: 0.622400
# Epoch 51, CIFAR-10 Batch 3:  | Loss:     0.5700 | Validation Accuracy: 0.623400
# Epoch 51, CIFAR-10 Batch 4:  | Loss:     0.5997 | Validation Accuracy: 0.616600
# Epoch 51, CIFAR-10 Batch 5:  | Loss:     0.5865 | Validation Accuracy: 0.624800
# Epoch 52, CIFAR-10 Batch 1:  | Loss:     0.6419 | Validation Accuracy: 0.624800
# Epoch 52, CIFAR-10 Batch 2:  | Loss:     0.6599 | Validation Accuracy: 0.620600
# Epoch 52, CIFAR-10 Batch 3:  | Loss:     0.5639 | Validation Accuracy: 0.620000
# Epoch 52, CIFAR-10 Batch 4:  | Loss:     0.5770 | Validation Accuracy: 0.616000
# Epoch 52, CIFAR-10 Batch 5:  | Loss:     0.6032 | Validation Accuracy: 0.624200
# Epoch 53, CIFAR-10 Batch 1:  | Loss:     0.6239 | Validation Accuracy: 0.621600
# Epoch 53, CIFAR-10 Batch 2:  | Loss:     0.6364 | Validation Accuracy: 0.626200
# Epoch 53, CIFAR-10 Batch 3:  | Loss:     0.5555 | Validation Accuracy: 0.628400
# Epoch 53, CIFAR-10 Batch 4:  | Loss:     0.5840 | Validation Accuracy: 0.621400
# Epoch 53, CIFAR-10 Batch 5:  | Loss:     0.6193 | Validation Accuracy: 0.621400
# Epoch 54, CIFAR-10 Batch 1:  | Loss:     0.6119 | Validation Accuracy: 0.622000
# Epoch 54, CIFAR-10 Batch 2:  | Loss:     0.6308 | Validation Accuracy: 0.624200
# Epoch 54, CIFAR-10 Batch 3:  | Loss:     0.5361 | Validation Accuracy: 0.625200
# Epoch 54, CIFAR-10 Batch 4:  | Loss:     0.5320 | Validation Accuracy: 0.629800
# Epoch 54, CIFAR-10 Batch 5:  | Loss:     0.5486 | Validation Accuracy: 0.640000
# Epoch 55, CIFAR-10 Batch 1:  | Loss:     0.5937 | Validation Accuracy: 0.624600
# Epoch 55, CIFAR-10 Batch 2:  | Loss:     0.6133 | Validation Accuracy: 0.627000
# Epoch 55, CIFAR-10 Batch 3:  | Loss:     0.5256 | Validation Accuracy: 0.626400
# Epoch 55, CIFAR-10 Batch 4:  | Loss:     0.5194 | Validation Accuracy: 0.631800
# Epoch 55, CIFAR-10 Batch 5:  | Loss:     0.5453 | Validation Accuracy: 0.633800
# Epoch 56, CIFAR-10 Batch 1:  | Loss:     0.5888 | Validation Accuracy: 0.626400
# Epoch 56, CIFAR-10 Batch 2:  | Loss:     0.6045 | Validation Accuracy: 0.625800
# Epoch 56, CIFAR-10 Batch 3:  | Loss:     0.5085 | Validation Accuracy: 0.630200
# Epoch 56, CIFAR-10 Batch 4:  | Loss:     0.5419 | Validation Accuracy: 0.627600
# Epoch 56, CIFAR-10 Batch 5:  | Loss:     0.5533 | Validation Accuracy: 0.626400
# Epoch 57, CIFAR-10 Batch 1:  | Loss:     0.5720 | Validation Accuracy: 0.628800
# Epoch 57, CIFAR-10 Batch 2:  | Loss:     0.5951 | Validation Accuracy: 0.627600
# Epoch 57, CIFAR-10 Batch 3:  | Loss:     0.4875 | Validation Accuracy: 0.632200
# Epoch 57, CIFAR-10 Batch 4:  | Loss:     0.5121 | Validation Accuracy: 0.628800
# Epoch 57, CIFAR-10 Batch 5:  | Loss:     0.5272 | Validation Accuracy: 0.628200
# Epoch 58, CIFAR-10 Batch 1:  | Loss:     0.5633 | Validation Accuracy: 0.630600
# Epoch 58, CIFAR-10 Batch 2:  | Loss:     0.5856 | Validation Accuracy: 0.615600
# Epoch 58, CIFAR-10 Batch 3:  | Loss:     0.5053 | Validation Accuracy: 0.630200
# Epoch 58, CIFAR-10 Batch 4:  | Loss:     0.5692 | Validation Accuracy: 0.613000
# Epoch 58, CIFAR-10 Batch 5:  | Loss:     0.5183 | Validation Accuracy: 0.627400
# Epoch 59, CIFAR-10 Batch 1:  | Loss:     0.5819 | Validation Accuracy: 0.626200
# Epoch 59, CIFAR-10 Batch 2:  | Loss:     0.6538 | Validation Accuracy: 0.588800
# Epoch 59, CIFAR-10 Batch 3:  | Loss:     0.5334 | Validation Accuracy: 0.624600
# Epoch 59, CIFAR-10 Batch 4:  | Loss:     0.4923 | Validation Accuracy: 0.628600
# Epoch 59, CIFAR-10 Batch 5:  | Loss:     0.5827 | Validation Accuracy: 0.614200
# Epoch 60, CIFAR-10 Batch 1:  | Loss:     0.5641 | Validation Accuracy: 0.628600
# Epoch 60, CIFAR-10 Batch 2:  | Loss:     0.6124 | Validation Accuracy: 0.596400
# Epoch 60, CIFAR-10 Batch 3:  | Loss:     0.5110 | Validation Accuracy: 0.621000
# Epoch 60, CIFAR-10 Batch 4:  | Loss:     0.4737 | Validation Accuracy: 0.633800
# Epoch 60, CIFAR-10 Batch 5:  | Loss:     0.5107 | Validation Accuracy: 0.627800
# Epoch 61, CIFAR-10 Batch 1:  | Loss:     0.5379 | Validation Accuracy: 0.628200
# Epoch 61, CIFAR-10 Batch 2:  | Loss:     0.5905 | Validation Accuracy: 0.600400
# Epoch 61, CIFAR-10 Batch 3:  | Loss:     0.4974 | Validation Accuracy: 0.631400
# Epoch 61, CIFAR-10 Batch 4:  | Loss:     0.4601 | Validation Accuracy: 0.633400
# Epoch 61, CIFAR-10 Batch 5:  | Loss:     0.4831 | Validation Accuracy: 0.630600
# Epoch 62, CIFAR-10 Batch 1:  | Loss:     0.5321 | Validation Accuracy: 0.627400
# Epoch 62, CIFAR-10 Batch 2:  | Loss:     0.5897 | Validation Accuracy: 0.607400
# Epoch 62, CIFAR-10 Batch 3:  | Loss:     0.4971 | Validation Accuracy: 0.621400
# Epoch 62, CIFAR-10 Batch 4:  | Loss:     0.4494 | Validation Accuracy: 0.632200
# Epoch 62, CIFAR-10 Batch 5:  | Loss:     0.4818 | Validation Accuracy: 0.631200
# Epoch 63, CIFAR-10 Batch 1:  | Loss:     0.5222 | Validation Accuracy: 0.629600
# Epoch 63, CIFAR-10 Batch 2:  | Loss:     0.5556 | Validation Accuracy: 0.610800
# Epoch 63, CIFAR-10 Batch 3:  | Loss:     0.4849 | Validation Accuracy: 0.624800
# Epoch 63, CIFAR-10 Batch 4:  | Loss:     0.4398 | Validation Accuracy: 0.628800
# Epoch 63, CIFAR-10 Batch 5:  | Loss:     0.4587 | Validation Accuracy: 0.626800
# Epoch 64, CIFAR-10 Batch 1:  | Loss:     0.5024 | Validation Accuracy: 0.635200
# Epoch 64, CIFAR-10 Batch 2:  | Loss:     0.5468 | Validation Accuracy: 0.614200
# Epoch 64, CIFAR-10 Batch 3:  | Loss:     0.4466 | Validation Accuracy: 0.627600
# Epoch 64, CIFAR-10 Batch 4:  | Loss:     0.4268 | Validation Accuracy: 0.628800
# Epoch 64, CIFAR-10 Batch 5:  | Loss:     0.4699 | Validation Accuracy: 0.630000
# Epoch 65, CIFAR-10 Batch 1:  | Loss:     0.4974 | Validation Accuracy: 0.633200
# Epoch 65, CIFAR-10 Batch 2:  | Loss:     0.5169 | Validation Accuracy: 0.617200
# Epoch 65, CIFAR-10 Batch 3:  | Loss:     0.4315 | Validation Accuracy: 0.627400
# Epoch 65, CIFAR-10 Batch 4:  | Loss:     0.4119 | Validation Accuracy: 0.633400
# Epoch 65, CIFAR-10 Batch 5:  | Loss:     0.4389 | Validation Accuracy: 0.630600
# Epoch 66, CIFAR-10 Batch 1:  | Loss:     0.4781 | Validation Accuracy: 0.638400
# Epoch 66, CIFAR-10 Batch 2:  | Loss:     0.4985 | Validation Accuracy: 0.620000
# Epoch 66, CIFAR-10 Batch 3:  | Loss:     0.4271 | Validation Accuracy: 0.626600
# Epoch 66, CIFAR-10 Batch 4:  | Loss:     0.4119 | Validation Accuracy: 0.632600
# Epoch 66, CIFAR-10 Batch 5:  | Loss:     0.4196 | Validation Accuracy: 0.635400
# Epoch 67, CIFAR-10 Batch 1:  | Loss:     0.4499 | Validation Accuracy: 0.634800
# Epoch 67, CIFAR-10 Batch 2:  | Loss:     0.4996 | Validation Accuracy: 0.622800
# Epoch 67, CIFAR-10 Batch 3:  | Loss:     0.4429 | Validation Accuracy: 0.630000
# Epoch 67, CIFAR-10 Batch 4:  | Loss:     0.4034 | Validation Accuracy: 0.630600
# Epoch 67, CIFAR-10 Batch 5:  | Loss:     0.4278 | Validation Accuracy: 0.629000
# Epoch 68, CIFAR-10 Batch 1:  | Loss:     0.4474 | Validation Accuracy: 0.641600
# Epoch 68, CIFAR-10 Batch 2:  | Loss:     0.4703 | Validation Accuracy: 0.624000
# Epoch 68, CIFAR-10 Batch 3:  | Loss:     0.4192 | Validation Accuracy: 0.630800
# Epoch 68, CIFAR-10 Batch 4:  | Loss:     0.3907 | Validation Accuracy: 0.639800
# Epoch 68, CIFAR-10 Batch 5:  | Loss:     0.4038 | Validation Accuracy: 0.634800
# Epoch 69, CIFAR-10 Batch 1:  | Loss:     0.4456 | Validation Accuracy: 0.635800
# Epoch 69, CIFAR-10 Batch 2:  | Loss:     0.4749 | Validation Accuracy: 0.618000
# Epoch 69, CIFAR-10 Batch 3:  | Loss:     0.4096 | Validation Accuracy: 0.638000
# Epoch 69, CIFAR-10 Batch 4:  | Loss:     0.3938 | Validation Accuracy: 0.630200
# Epoch 69, CIFAR-10 Batch 5:  | Loss:     0.4221 | Validation Accuracy: 0.634200
# Epoch 70, CIFAR-10 Batch 1:  | Loss:     0.4536 | Validation Accuracy: 0.628000
# Epoch 70, CIFAR-10 Batch 2:  | Loss:     0.4790 | Validation Accuracy: 0.609000
# Epoch 70, CIFAR-10 Batch 3:  | Loss:     0.3796 | Validation Accuracy: 0.631600
# Epoch 70, CIFAR-10 Batch 4:  | Loss:     0.3676 | Validation Accuracy: 0.629600
# Epoch 70, CIFAR-10 Batch 5:  | Loss:     0.4137 | Validation Accuracy: 0.628400
# Epoch 71, CIFAR-10 Batch 1:  | Loss:     0.4062 | Validation Accuracy: 0.635600
# Epoch 71, CIFAR-10 Batch 2:  | Loss:     0.4498 | Validation Accuracy: 0.626200
# Epoch 71, CIFAR-10 Batch 3:  | Loss:     0.4142 | Validation Accuracy: 0.618000
# Epoch 71, CIFAR-10 Batch 4:  | Loss:     0.3759 | Validation Accuracy: 0.627000
# Epoch 71, CIFAR-10 Batch 5:  | Loss:     0.3871 | Validation Accuracy: 0.632600
# Epoch 72, CIFAR-10 Batch 1:  | Loss:     0.4301 | Validation Accuracy: 0.628600
# Epoch 72, CIFAR-10 Batch 2:  | Loss:     0.4527 | Validation Accuracy: 0.631600
# Epoch 72, CIFAR-10 Batch 3:  | Loss:     0.4103 | Validation Accuracy: 0.622800
# Epoch 72, CIFAR-10 Batch 4:  | Loss:     0.3475 | Validation Accuracy: 0.626000
# Epoch 72, CIFAR-10 Batch 5:  | Loss:     0.3768 | Validation Accuracy: 0.630600
# Epoch 73, CIFAR-10 Batch 1:  | Loss:     0.4368 | Validation Accuracy: 0.617400
# Epoch 73, CIFAR-10 Batch 2:  | Loss:     0.4351 | Validation Accuracy: 0.629800
# Epoch 73, CIFAR-10 Batch 3:  | Loss:     0.3795 | Validation Accuracy: 0.623600
# Epoch 73, CIFAR-10 Batch 4:  | Loss:     0.3589 | Validation Accuracy: 0.627200
# Epoch 73, CIFAR-10 Batch 5:  | Loss:     0.3876 | Validation Accuracy: 0.632800
# Epoch 74, CIFAR-10 Batch 1:  | Loss:     0.4309 | Validation Accuracy: 0.611600
# Epoch 74, CIFAR-10 Batch 2:  | Loss:     0.4424 | Validation Accuracy: 0.621000
# Epoch 74, CIFAR-10 Batch 3:  | Loss:     0.3666 | Validation Accuracy: 0.622800
# Epoch 74, CIFAR-10 Batch 4:  | Loss:     0.3631 | Validation Accuracy: 0.615600
# Epoch 74, CIFAR-10 Batch 5:  | Loss:     0.3670 | Validation Accuracy: 0.632000
# Epoch 75, CIFAR-10 Batch 1:  | Loss:     0.4427 | Validation Accuracy: 0.611600
# Epoch 75, CIFAR-10 Batch 2:  | Loss:     0.4386 | Validation Accuracy: 0.624800
# Epoch 75, CIFAR-10 Batch 3:  | Loss:     0.3879 | Validation Accuracy: 0.624200
# Epoch 75, CIFAR-10 Batch 4:  | Loss:     0.3435 | Validation Accuracy: 0.622400
# Epoch 75, CIFAR-10 Batch 5:  | Loss:     0.3385 | Validation Accuracy: 0.631600
# Epoch 76, CIFAR-10 Batch 1:  | Loss:     0.4006 | Validation Accuracy: 0.615600
# Epoch 76, CIFAR-10 Batch 2:  | Loss:     0.4552 | Validation Accuracy: 0.617200
# Epoch 76, CIFAR-10 Batch 3:  | Loss:     0.3668 | Validation Accuracy: 0.620600
# Epoch 76, CIFAR-10 Batch 4:  | Loss:     0.3444 | Validation Accuracy: 0.622000
# Epoch 76, CIFAR-10 Batch 5:  | Loss:     0.3663 | Validation Accuracy: 0.626200
# Epoch 77, CIFAR-10 Batch 1:  | Loss:     0.3818 | Validation Accuracy: 0.626800
# Epoch 77, CIFAR-10 Batch 2:  | Loss:     0.4309 | Validation Accuracy: 0.616200
# Epoch 77, CIFAR-10 Batch 3:  | Loss:     0.3492 | Validation Accuracy: 0.618200
# Epoch 77, CIFAR-10 Batch 4:  | Loss:     0.3487 | Validation Accuracy: 0.622000
# Epoch 77, CIFAR-10 Batch 5:  | Loss:     0.3502 | Validation Accuracy: 0.624400
# Epoch 78, CIFAR-10 Batch 1:  | Loss:     0.3729 | Validation Accuracy: 0.624800
# Epoch 78, CIFAR-10 Batch 2:  | Loss:     0.3916 | Validation Accuracy: 0.619400
# Epoch 78, CIFAR-10 Batch 3:  | Loss:     0.3541 | Validation Accuracy: 0.617000
# Epoch 78, CIFAR-10 Batch 4:  | Loss:     0.3308 | Validation Accuracy: 0.621600
# Epoch 78, CIFAR-10 Batch 5:  | Loss:     0.3640 | Validation Accuracy: 0.620800
# Epoch 79, CIFAR-10 Batch 1:  | Loss:     0.3529 | Validation Accuracy: 0.631600
# Epoch 79, CIFAR-10 Batch 2:  | Loss:     0.3814 | Validation Accuracy: 0.626400
# Epoch 79, CIFAR-10 Batch 3:  | Loss:     0.3423 | Validation Accuracy: 0.624200
# Epoch 79, CIFAR-10 Batch 4:  | Loss:     0.3613 | Validation Accuracy: 0.615600
# Epoch 79, CIFAR-10 Batch 5:  | Loss:     0.3478 | Validation Accuracy: 0.624800
# Epoch 80, CIFAR-10 Batch 1:  | Loss:     0.3663 | Validation Accuracy: 0.628800
# Epoch 80, CIFAR-10 Batch 2:  | Loss:     0.3742 | Validation Accuracy: 0.621600
# Epoch 80, CIFAR-10 Batch 3:  | Loss:     0.3332 | Validation Accuracy: 0.627600
# Epoch 80, CIFAR-10 Batch 4:  | Loss:     0.3375 | Validation Accuracy: 0.614000
# Epoch 80, CIFAR-10 Batch 5:  | Loss:     0.3481 | Validation Accuracy: 0.617400
# Epoch 81, CIFAR-10 Batch 1:  | Loss:     0.3646 | Validation Accuracy: 0.629200
# Epoch 81, CIFAR-10 Batch 2:  | Loss:     0.3664 | Validation Accuracy: 0.625400
# Epoch 81, CIFAR-10 Batch 3:  | Loss:     0.3024 | Validation Accuracy: 0.627400
# Epoch 81, CIFAR-10 Batch 4:  | Loss:     0.3083 | Validation Accuracy: 0.617600
# Epoch 81, CIFAR-10 Batch 5:  | Loss:     0.3331 | Validation Accuracy: 0.622000
# Epoch 82, CIFAR-10 Batch 1:  | Loss:     0.3595 | Validation Accuracy: 0.630200
# Epoch 82, CIFAR-10 Batch 2:  | Loss:     0.3560 | Validation Accuracy: 0.629200
# Epoch 82, CIFAR-10 Batch 3:  | Loss:     0.2960 | Validation Accuracy: 0.632200
# Epoch 82, CIFAR-10 Batch 4:  | Loss:     0.2867 | Validation Accuracy: 0.623000
# Epoch 82, CIFAR-10 Batch 5:  | Loss:     0.3225 | Validation Accuracy: 0.613000
# Epoch 83, CIFAR-10 Batch 1:  | Loss:     0.3304 | Validation Accuracy: 0.633000
# Epoch 83, CIFAR-10 Batch 2:  | Loss:     0.3605 | Validation Accuracy: 0.621200
# Epoch 83, CIFAR-10 Batch 3:  | Loss:     0.3084 | Validation Accuracy: 0.623600
# Epoch 83, CIFAR-10 Batch 4:  | Loss:     0.2878 | Validation Accuracy: 0.623200
# Epoch 83, CIFAR-10 Batch 5:  | Loss:     0.3059 | Validation Accuracy: 0.620600
# Epoch 84, CIFAR-10 Batch 1:  | Loss:     0.3471 | Validation Accuracy: 0.629800
# Epoch 84, CIFAR-10 Batch 2:  | Loss:     0.3448 | Validation Accuracy: 0.631000
# Epoch 84, CIFAR-10 Batch 3:  | Loss:     0.2819 | Validation Accuracy: 0.634000
# Epoch 84, CIFAR-10 Batch 4:  | Loss:     0.2681 | Validation Accuracy: 0.626000
# Epoch 84, CIFAR-10 Batch 5:  | Loss:     0.3226 | Validation Accuracy: 0.615000
# Epoch 85, CIFAR-10 Batch 1:  | Loss:     0.3316 | Validation Accuracy: 0.630000
# Epoch 85, CIFAR-10 Batch 2:  | Loss:     0.3232 | Validation Accuracy: 0.628600
# Epoch 85, CIFAR-10 Batch 3:  | Loss:     0.3140 | Validation Accuracy: 0.626200
# Epoch 85, CIFAR-10 Batch 4:  | Loss:     0.2749 | Validation Accuracy: 0.614400
# Epoch 85, CIFAR-10 Batch 5:  | Loss:     0.3071 | Validation Accuracy: 0.613800
# Epoch 86, CIFAR-10 Batch 1:  | Loss:     0.3269 | Validation Accuracy: 0.623400
# Epoch 86, CIFAR-10 Batch 2:  | Loss:     0.3360 | Validation Accuracy: 0.617200
# Epoch 86, CIFAR-10 Batch 3:  | Loss:     0.2991 | Validation Accuracy: 0.621800
# Epoch 86, CIFAR-10 Batch 4:  | Loss:     0.2875 | Validation Accuracy: 0.612600
# Epoch 86, CIFAR-10 Batch 5:  | Loss:     0.2978 | Validation Accuracy: 0.613200
# Epoch 87, CIFAR-10 Batch 1:  | Loss:     0.3162 | Validation Accuracy: 0.622400
# Epoch 87, CIFAR-10 Batch 2:  | Loss:     0.3256 | Validation Accuracy: 0.619200
# Epoch 87, CIFAR-10 Batch 3:  | Loss:     0.3091 | Validation Accuracy: 0.626600
# Epoch 87, CIFAR-10 Batch 4:  | Loss:     0.2727 | Validation Accuracy: 0.618200
# Epoch 87, CIFAR-10 Batch 5:  | Loss:     0.3051 | Validation Accuracy: 0.611600
# Epoch 88, CIFAR-10 Batch 1:  | Loss:     0.2949 | Validation Accuracy: 0.628000
# Epoch 88, CIFAR-10 Batch 2:  | Loss:     0.3304 | Validation Accuracy: 0.623200
# Epoch 88, CIFAR-10 Batch 3:  | Loss:     0.2644 | Validation Accuracy: 0.625000
# Epoch 88, CIFAR-10 Batch 4:  | Loss:     0.2395 | Validation Accuracy: 0.617200
# Epoch 88, CIFAR-10 Batch 5:  | Loss:     0.2697 | Validation Accuracy: 0.622400
# Epoch 89, CIFAR-10 Batch 1:  | Loss:     0.2854 | Validation Accuracy: 0.634400
# Epoch 89, CIFAR-10 Batch 2:  | Loss:     0.2978 | Validation Accuracy: 0.622400
# Epoch 89, CIFAR-10 Batch 3:  | Loss:     0.2618 | Validation Accuracy: 0.629000
# Epoch 89, CIFAR-10 Batch 4:  | Loss:     0.2549 | Validation Accuracy: 0.616600
# Epoch 89, CIFAR-10 Batch 5:  | Loss:     0.2620 | Validation Accuracy: 0.623000
# Epoch 90, CIFAR-10 Batch 1:  | Loss:     0.2913 | Validation Accuracy: 0.630800
# Epoch 90, CIFAR-10 Batch 2:  | Loss:     0.3021 | Validation Accuracy: 0.622000
# Epoch 90, CIFAR-10 Batch 3:  | Loss:     0.2522 | Validation Accuracy: 0.630600
# Epoch 90, CIFAR-10 Batch 4:  | Loss:     0.2450 | Validation Accuracy: 0.624600
# Epoch 90, CIFAR-10 Batch 5:  | Loss:     0.2571 | Validation Accuracy: 0.625600
# Epoch 91, CIFAR-10 Batch 1:  | Loss:     0.2761 | Validation Accuracy: 0.630000
# Epoch 91, CIFAR-10 Batch 2:  | Loss:     0.2941 | Validation Accuracy: 0.623200
# Epoch 91, CIFAR-10 Batch 3:  | Loss:     0.2530 | Validation Accuracy: 0.627400
# Epoch 91, CIFAR-10 Batch 4:  | Loss:     0.2377 | Validation Accuracy: 0.622200
# Epoch 91, CIFAR-10 Batch 5:  | Loss:     0.2460 | Validation Accuracy: 0.626000
# Epoch 92, CIFAR-10 Batch 1:  | Loss:     0.2668 | Validation Accuracy: 0.628200
# Epoch 92, CIFAR-10 Batch 2:  | Loss:     0.2944 | Validation Accuracy: 0.623400
# Epoch 92, CIFAR-10 Batch 3:  | Loss:     0.2555 | Validation Accuracy: 0.630200
# Epoch 92, CIFAR-10 Batch 4:  | Loss:     0.2259 | Validation Accuracy: 0.613000
# Epoch 92, CIFAR-10 Batch 5:  | Loss:     0.2309 | Validation Accuracy: 0.625600
# Epoch 93, CIFAR-10 Batch 1:  | Loss:     0.2576 | Validation Accuracy: 0.624400
# Epoch 93, CIFAR-10 Batch 2:  | Loss:     0.2806 | Validation Accuracy: 0.624800
# Epoch 93, CIFAR-10 Batch 3:  | Loss:     0.2285 | Validation Accuracy: 0.634000
# Epoch 93, CIFAR-10 Batch 4:  | Loss:     0.2149 | Validation Accuracy: 0.617400
# Epoch 93, CIFAR-10 Batch 5:  | Loss:     0.2443 | Validation Accuracy: 0.614400
# Epoch 94, CIFAR-10 Batch 1:  | Loss:     0.2546 | Validation Accuracy: 0.624400
# Epoch 94, CIFAR-10 Batch 2:  | Loss:     0.2742 | Validation Accuracy: 0.618200
# Epoch 94, CIFAR-10 Batch 3:  | Loss:     0.2395 | Validation Accuracy: 0.633800
# Epoch 94, CIFAR-10 Batch 4:  | Loss:     0.2044 | Validation Accuracy: 0.621800
# Epoch 94, CIFAR-10 Batch 5:  | Loss:     0.2411 | Validation Accuracy: 0.619600
# Epoch 95, CIFAR-10 Batch 1:  | Loss:     0.2478 | Validation Accuracy: 0.625800
# Epoch 95, CIFAR-10 Batch 2:  | Loss:     0.2625 | Validation Accuracy: 0.622400
# Epoch 95, CIFAR-10 Batch 3:  | Loss:     0.2390 | Validation Accuracy: 0.624800
# Epoch 95, CIFAR-10 Batch 4:  | Loss:     0.2197 | Validation Accuracy: 0.617200
# Epoch 95, CIFAR-10 Batch 5:  | Loss:     0.2419 | Validation Accuracy: 0.621400
# Epoch 96, CIFAR-10 Batch 1:  | Loss:     0.2362 | Validation Accuracy: 0.627200
# Epoch 96, CIFAR-10 Batch 2:  | Loss:     0.2834 | Validation Accuracy: 0.620800
# Epoch 96, CIFAR-10 Batch 3:  | Loss:     0.2306 | Validation Accuracy: 0.629800
# Epoch 96, CIFAR-10 Batch 4:  | Loss:     0.2221 | Validation Accuracy: 0.619200
# Epoch 96, CIFAR-10 Batch 5:  | Loss:     0.2308 | Validation Accuracy: 0.618600
# Epoch 97, CIFAR-10 Batch 1:  | Loss:     0.2467 | Validation Accuracy: 0.628000
# Epoch 97, CIFAR-10 Batch 2:  | Loss:     0.2707 | Validation Accuracy: 0.626800
# Epoch 97, CIFAR-10 Batch 3:  | Loss:     0.2292 | Validation Accuracy: 0.629400
# Epoch 97, CIFAR-10 Batch 4:  | Loss:     0.2017 | Validation Accuracy: 0.618000
# Epoch 97, CIFAR-10 Batch 5:  | Loss:     0.2315 | Validation Accuracy: 0.626400
# Epoch 98, CIFAR-10 Batch 1:  | Loss:     0.2462 | Validation Accuracy: 0.626600
# Epoch 98, CIFAR-10 Batch 2:  | Loss:     0.2715 | Validation Accuracy: 0.628800
# Epoch 98, CIFAR-10 Batch 3:  | Loss:     0.2197 | Validation Accuracy: 0.628800
# Epoch 98, CIFAR-10 Batch 4:  | Loss:     0.2375 | Validation Accuracy: 0.607200
# Epoch 98, CIFAR-10 Batch 5:  | Loss:     0.2237 | Validation Accuracy: 0.624800
# Epoch 99, CIFAR-10 Batch 1:  | Loss:     0.2527 | Validation Accuracy: 0.624200
# Epoch 99, CIFAR-10 Batch 2:  | Loss:     0.2484 | Validation Accuracy: 0.631200
# Epoch 99, CIFAR-10 Batch 3:  | Loss:     0.2017 | Validation Accuracy: 0.631600
# Epoch 99, CIFAR-10 Batch 4:  | Loss:     0.2237 | Validation Accuracy: 0.619600
# Epoch 99, CIFAR-10 Batch 5:  | Loss:     0.2258 | Validation Accuracy: 0.625200
# Epoch 100, CIFAR-10 Batch 1:  | Loss:     0.2319 | Validation Accuracy: 0.630000
# Epoch 100, CIFAR-10 Batch 2:  | Loss:     0.2536 | Validation Accuracy: 0.631400
# Epoch 100, CIFAR-10 Batch 3:  | Loss:     0.2175 | Validation Accuracy: 0.629200
# Epoch 100, CIFAR-10 Batch 4:  | Loss:     0.2067 | Validation Accuracy: 0.618000
# Epoch 100, CIFAR-10 Batch 5:  | Loss:     0.2427 | Validation Accuracy: 0.624000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6201574027538299

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
